# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# import sklearn stuff like train_test_split, StandardScaler, linearregression, randomforestregressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#   City Name   Latitude   Longitude  Elevation (m)  Temperature (°C)  \
# 0  City_236  40.014907  135.759794    1657.234222         32.140727
# 1  City_487 -81.752906   67.784550    1781.007943         28.199772
# 2   City_21  20.126899   33.924075    3140.598901         11.492930
# 3  City_216 -47.308667  154.638241     992.282813         34.909265
# 4  City_292 -83.425194   31.018268     597.192562         28.465786
#
#     Land Cover  Population Density (people/km²)  Energy Consumption (kWh)  \
# 0   Industrial                       638.140184              29866.608120
# 1        Water                      2757.814606              25461.567500
# 2        Water                      6020.462986               2539.737270
# 3  Green Space                      9491.952711              32146.724390
# 4        Water                      5191.476501               2513.126338
#
#    Air Quality Index (AQI)  Urban Greenness Ratio (%)  \
# 0                90.967582                  51.032061
# 1               121.919061                  17.819991
# 2               169.190188                  51.045248
# 3                90.989624                  19.211930
# 4                92.082516                  51.178231
#
#    Health Impact (Mortality Rate/100k)  Wind Speed (km/h)  Humidity (%)  \
# 0                            20.060893           0.017909     46.681317
# 1                            45.591306           1.585266     43.291975
# 2                            10.525874           8.614523     76.935296
# 3                            49.900393           0.297596     42.739059
# 4                            21.993127          19.375498     43.509082
#
#    Annual Rainfall (mm)  GDP per Capita (USD)
# 0           1750.054664           13551.38192
# 1            758.591768           41967.28373
# 2           2494.912602           17335.37251
# 3           1762.646698           31400.53605
# 4           2134.723878           27399.94789

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118055 entries, 0 to 118054
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   City Name                            118055 non-null  object
#  1   Latitude                             118055 non-null  float64
#  2   Longitude                            117906 non-null  float64
#  3   Elevation (m)                        118055 non-null  float64
#  4   Temperature (°C)                     118055 non-null  float64
#  5   Land Cover                           118055 non-null  object
#  6   Population Density (people/km²)      118055 non-null  float64
#  7   Energy Consumption (kWh)             117890 non-null  float64
#  8   Air Quality Index (AQI)              118055 non-null  float64
#  9   Urban Greenness Ratio (%)            118055 non-null  float64
#  10  Health Impact (Mortality Rate/100k)  118055 non-null  float64
#  11  Wind Speed (km/h)                    118055 non-null  float64
#  12  Humidity (%)                         117897 non-null  float64
#  13  Annual Rainfall (mm)                 118055 non-null  float64
#  14  GDP per Capita (USD)                 118055 non-null  float64
# dtypes: float64(13), object(2)
# memory usage: 13.5+ MB

# %%
df.describe()
# Out:
#             Latitude      Longitude  Elevation (m)  Temperature (°C)  \
# count  118055.000000  117906.000000  118055.000000     118055.000000
# mean        0.063600      -6.587757    2327.957333         22.406477
# std        53.688671     102.799904    1334.419025          7.169656
# min       -89.368361    -178.763581      22.164217         10.052493
# 25%       -46.424578     -97.664182    1088.754725         16.020114
# 50%         2.932161     -10.229466    2429.286256         22.701893
# 75%        46.416121      82.083902    3495.361860         28.432071
# max        88.936789     180.322476    4509.833682         35.073791
#
#        Population Density (people/km²)  Energy Consumption (kWh)  \
# count                    118055.000000             117890.000000
# mean                       5236.460289              26177.192182
# std                        2691.600552              14009.853574
# min                         504.427341               1018.388794
# 25%                        2781.430204              14092.780615
# 50%                        5279.746380              26837.714635
# 75%                        7479.845057              38404.838475
# max                       10021.092840              50125.983500
#
#        Air Quality Index (AQI)  Urban Greenness Ratio (%)  \
# count            118055.000000              118055.000000
# mean                117.928298                  34.271996
# std                  48.496328                  14.353613
# min                  29.918825                  10.007400
# 25%                  77.098125                  21.714111
# 50%                 117.007111                  33.173251
# 75%                 160.942839                  47.075378
# max                 199.858713                  60.136742
#
#        Health Impact (Mortality Rate/100k)  Wind Speed (km/h)   Humidity (%)  \
# count                        118055.000000      118055.000000  117897.000000
# mean                             24.169256          15.190071      59.637260
# std                              14.014521           8.725308      11.359611
# min                               0.001532           0.006790      40.111715
# 25%                              12.013701           7.472904      50.416814
# 50%                              24.994689          14.777760      59.075634
# 75%                              34.607529          22.948420      68.988991
# max                              50.048999          29.985588      80.203387
#
#        Annual Rainfall (mm)  GDP per Capita (USD)
# count         118055.000000         118055.000000
# mean            1510.617984          25221.018525
# std              590.449197          14262.275868
# min              512.771569           1188.861205
# 25%              974.354274          12900.863320
# 50%             1535.657857          25144.154480
# 75%             2023.547441          38122.328610
# max             2504.278483          50124.176710

# %%
df.isnull().sum()
# Out:
# City Name                                0
# Latitude                                 0
# Longitude                              149
# Elevation (m)                            0
# Temperature (°C)                         0
# Land Cover                               0
# Population Density (people/km²)          0
# Energy Consumption (kWh)               165
# Air Quality Index (AQI)                  0
# Urban Greenness Ratio (%)                0
# Health Impact (Mortality Rate/100k)      0
# Wind Speed (km/h)                        0
# Humidity (%)                           158
# Annual Rainfall (mm)                     0
# GDP per Capita (USD)                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(55)

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Energy Consumption (kWh)'], bins=20, edgecolor='k')
plt.title('Histogram of Energy Consumption')
plt.xlabel('Energy Consumption (kWh)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Health Impact (Mortality Rate/100k)'], bins=20, edgecolor='k')
plt.title('Histogram of Health Impact (Mortality Rate/100k)')
plt.xlabel('Health Impact (Mortality Rate/100k)')
plt.ylabel('Frequency')
plt.show()

# %%
# make plot for Temperature (°C)

plt.figure(figsize=(10, 6))
plt.hist(df['Temperature (°C)'], bins=20, edgecolor='k')
plt.title('Histogram of Temperature (°C)')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')
plt.show()

# %%
# data cleaning
df.columns
# Out:
# Index(['City Name', 'Latitude', 'Longitude', 'Elevation (m)',
#        'Temperature (°C)', 'Land Cover', 'Population Density (people/km²)',
#        'Energy Consumption (kWh)', 'Air Quality Index (AQI)',
#        'Urban Greenness Ratio (%)', 'Health Impact (Mortality Rate/100k)',
#        'Wind Speed (km/h)', 'Humidity (%)', 'Annual Rainfall (mm)',
#        'GDP per Capita (USD)'],
#       dtype='object')

# %%
num_cols = df.select_dtypes(include=['number']).columns.drop('Health Impact (Mortality Rate/100k)')
num_cols
# Out:
# Index(['Latitude', 'Longitude', 'Elevation (m)', 'Temperature (°C)',
#        'Population Density (people/km²)', 'Energy Consumption (kWh)',
#        'Air Quality Index (AQI)', 'Urban Greenness Ratio (%)',
#        'Wind Speed (km/h)', 'Humidity (%)', 'Annual Rainfall (mm)',
#        'GDP per Capita (USD)'],
#       dtype='object')

# %%
# impute columns with mean
df[num_cols] = df[num_cols].fillna(df[num_cols].median())
df.isnull().sum()
# Out:
# City Name                              0
# Latitude                               0
# Longitude                              0
# Elevation (m)                          0
# Temperature (°C)                       0
# Land Cover                             0
# Population Density (people/km²)        0
# Energy Consumption (kWh)               0
# Air Quality Index (AQI)                0
# Urban Greenness Ratio (%)              0
# Health Impact (Mortality Rate/100k)    0
# Wind Speed (km/h)                      0
# Humidity (%)                           0
# Annual Rainfall (mm)                   0
# GDP per Capita (USD)                   0
# dtype: int64

# %%
# remove duplicates
df.shape
# Out:
# (118055, 15)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (118000, 15)

# %%
# correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
# There appears to be no major correlation, however we have sufficient data to train a model and develop conclusions
